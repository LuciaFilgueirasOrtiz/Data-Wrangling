# %% [markdown]
# ***Carga y aproximación a la base de datos***

# %%
#importamos las librerías que necesitamos 
import pandas as pd
import numpy as np

# %%
#cargamos nuestras bases de datos
df1 = pd.read_csv('/content/p_data.csv',delimiter=';')
df2 = pd.read_csv('/content/w_data.csv',delimiter=';')

# %%
#vemos los primeros registros de la base 
df1.head()
# Out:
#     Age      Sex      ID    Race         Country   Education  Education-Num  \
# 0  39.0     Male   49084   White   United-States   Bachelors           13.0
# 1  50.0     Male   68553   White   United-States   Bachelors           13.0
# 2  38.0     Male  143654   White   United-States     HS-grad            9.0
# 3  53.0     Male   41510   Black   United-States        11th            7.0
# 4  28.0   Female  195025   Black            Cuba   Bachelors           13.0
#
#         Marital Status    Relationship
# 0        Never-married   Not-in-family
# 1   Married-civ-spouse         Husband
# 2             Divorced   Not-in-family
# 3   Married-civ-spouse         Husband
# 4   Married-civ-spouse            Wife

# %%
df2.head()
# Out:
#            Workclass    fnlwgt  Capital Gain  Capital Loss  Hours per week  \
# 0          State-gov   77516.0        2174.0           0.0            40.0
# 1   Self-emp-not-inc   83311.0           0.0           0.0            13.0
# 2            Private  215646.0           0.0           0.0            40.0
# 3            Private  234721.0           0.0           0.0            40.0
# 4            Private  338409.0           0.0           0.0            40.0
#
#        ID  Target
# 0   49084   <=50K
# 1   68553   <=50K
# 2  143654   <=50K
# 3   41510   <=50K
# 4  195025   <=50K

# %%
#vemos cómo se componen ambos dataset 
print('El df1 se compone de', df1.shape[0], 'filas y de', df1.shape[1], 'columnas')
# Out:
# El df1 se compone de 36975 filas y de 9 columnas

# %%
print('El df1 se compone de', df2.shape[0], 'filas y de', df2.shape[1], 'columnas')
# Out:
# El df1 se compone de 48843 filas y de 7 columnas

# %% [markdown]
# Vemos que el segundo dataframe tiene un registro más y dos columnas menos.

# %% [markdown]
# ***Unimos las dos tablas***

# %%
#eliminamos los duplicados de acuerdo a la columna id del df1 
df1.drop_duplicates('ID')
# Out:
#         Age      Sex         ID                 Race         Country  \
# 0      39.0     Male      49084                White   United-States
# 1      50.0     Male      68553                White   United-States
# 2      38.0     Male     143654                White   United-States
# 3      53.0     Male      41510                Black   United-States
# 4      28.0   Female     195025                Black            Cuba
# ...     ...      ...        ...                  ...             ...
# 36970  61.0   Female    6614929   Asian-Pac-Islander               ?
# 36971  44.0     Male  341416503                White          Mexico
# 36972  62.0     Male  236113110                White   United-States
# 36973  47.0   Female  316348175                White        Columbia
# 36974  35.0     Male  125945281                White   United-States
#
#         Education  Education-Num       Marital Status    Relationship
# ...

# %%
#eliminamos los duplicados de acuerdo a la columna id del df2 
df2.drop_duplicates('ID')
# Out:
#                Workclass    fnlwgt  Capital Gain  Capital Loss  \
# 0              State-gov   77516.0        2174.0           0.0
# 1       Self-emp-not-inc   83311.0           0.0           0.0
# 2                Private  215646.0           0.0           0.0
# 3                Private  234721.0           0.0           0.0
# 4                Private  338409.0           0.0           0.0
# ...                  ...       ...           ...           ...
# 48838            Private  215419.0           0.0           0.0
# 48839                  ?  321403.0           0.0           0.0
# 48840            Private  374983.0           0.0           0.0
# 48841            Private   83891.0        5455.0           0.0
# 48842       Self-emp-inc  182148.0           0.0           0.0
#
#        Hours per week          ID   Target
# 0                40.0       49084    <=50K
# 1                13.0       68553    <=50K
# 2                40.0      143654    <=50K
# ...

# %%
#realizamos la unión de los dos dataframes con un right merge ya que el segundo df tiene un registro más que el primero 
df_complete = pd.merge(df1, df2, on = 'ID', how='right', indicator=True)
print(f'El dataframe completo tiene {len(df_complete)} filas y {df_complete.shape[1]} columnas')
# Out:
# El dataframe completo tiene 48843 filas y 16 columnas

# %%
df_complete.head()
# Out:
#     Age      Sex      ID    Race         Country   Education  Education-Num  \
# 0  39.0     Male   49084   White   United-States   Bachelors           13.0
# 1  50.0     Male   68553   White   United-States   Bachelors           13.0
# 2  38.0     Male  143654   White   United-States     HS-grad            9.0
# 3  53.0     Male   41510   Black   United-States        11th            7.0
# 4  28.0   Female  195025   Black            Cuba   Bachelors           13.0
#
#         Marital Status    Relationship          Workclass    fnlwgt  \
# 0        Never-married   Not-in-family          State-gov   77516.0
# 1   Married-civ-spouse         Husband   Self-emp-not-inc   83311.0
# 2             Divorced   Not-in-family            Private  215646.0
# 3   Married-civ-spouse         Husband            Private  234721.0
# 4   Married-civ-spouse            Wife            Private  338409.0
#
#    Capital Gain  Capital Loss  Hours per week  Target _merge
# ...

# %% [markdown]
# ***Data Wrangling***

# %% [markdown]
# Establecemos el ID como índice y lo ordenamos de menor a mayor

# %%
df_complete.set_index('ID', inplace=True)

# %%
df_complete = df_complete.sort_index()

# %%
df_complete
# Out:
#              Age      Sex    Race         Country   Education  Education-Num  \
# ID
# 3080         NaN      NaN     NaN             NaN         NaN            NaN
# 7286        62.0     Male   White   United-States     HS-grad            9.0
# 7496        31.0   Female   White   United-States     Masters           14.0
# 9929         NaN      NaN     NaN             NaN         NaN            NaN
# 17968       25.0   Female   White   United-States     Masters           14.0
# ...          ...      ...     ...             ...         ...            ...
# 3199610067  31.0     Male   White   United-States   Bachelors           13.0
# 3200552514  19.0   Female   White   United-States     HS-grad            9.0
# 3200755724  28.0     Male   White   United-States     HS-grad            9.0
# 3225489111  43.0     Male   White          Mexico     HS-grad            9.0
# 3229272340  72.0     Male   White   United-States     HS-grad            9.0
#
# ...

# %%
#transformamos los nombres de las columnas a minuscula 
df_complete = df_complete.rename(columns={'Age': 'age', 'Sex': 'sex', 'Race': 'race', 'Country': 'country', 'Education': 'education', 'Target': 'target',
                                          'Education-Num': 'education-Num', 'Marital Status' : 'marital status','Relationship' : 'relationship',
                                          'Workclass': 'workclass','Capital Gain': 'capital gain', 'Capital Loss': 'capital loss', 'Hours per week': 'hours per week', '_merge': 'merge'})
df_complete
# Out:
#              age      sex    race         country   education  education-Num  \
# ID
# 3080         NaN      NaN     NaN             NaN         NaN            NaN
# 7286        62.0     Male   White   United-States     HS-grad            9.0
# 7496        31.0   Female   White   United-States     Masters           14.0
# 9929         NaN      NaN     NaN             NaN         NaN            NaN
# 17968       25.0   Female   White   United-States     Masters           14.0
# ...          ...      ...     ...             ...         ...            ...
# 3199610067  31.0     Male   White   United-States   Bachelors           13.0
# 3200552514  19.0   Female   White   United-States     HS-grad            9.0
# 3200755724  28.0     Male   White   United-States     HS-grad            9.0
# 3225489111  43.0     Male   White          Mexico     HS-grad            9.0
# 3229272340  72.0     Male   White   United-States     HS-grad            9.0
#
# ...

# %% [markdown]
# Para comparar cuales eran los registros que compartían el mismo ID, en el merge creamos una nueva columna que devuelve si el registro están en ambos df o left/right.

# %%
not_in_value = df_complete[df_complete['merge'] =='right_only']
not_in_value
# Out:
#             age  sex race country education  education-Num marital status  \
# ID
# 3080        NaN  NaN  NaN     NaN       NaN            NaN            NaN
# 9929        NaN  NaN  NaN     NaN       NaN            NaN            NaN
# 101857      NaN  NaN  NaN     NaN       NaN            NaN            NaN
# 258514      NaN  NaN  NaN     NaN       NaN            NaN            NaN
# 408522      NaN  NaN  NaN     NaN       NaN            NaN            NaN
# ...         ...  ...  ...     ...       ...            ...            ...
# 1579284144  NaN  NaN  NaN     NaN       NaN            NaN            NaN
# 1597985647  NaN  NaN  NaN     NaN       NaN            NaN            NaN
# 1600327123  NaN  NaN  NaN     NaN       NaN            NaN            NaN
# 1600575150  NaN  NaN  NaN     NaN       NaN            NaN            NaN
# 1610740286  NaN  NaN  NaN     NaN       NaN            NaN            NaN
#
# ...

# %% [markdown]
# Como vemos el ID 1344995623 es el que no tienen en común los dos df.

# %% [markdown]
# Transformamos los target a dos valores únicamente (‘<=50k’ y ‘>50k’) para poder analizarlos posteriormente.

# %%
#vemos cuáles son los distintos tipos de target que existen 
df_complete["target"].unique()
# Out:
# array([' >50K.', ' <=50K', ' >50K', ' <=50K.', nan], dtype=object)

# %%
df_complete['target'].replace([(' >50K.'), (' >50K')], '>50k', inplace=True)
df_complete['target'].replace([(' <=50K'), (' <=50K.')], '<=50k', inplace=True)

# %%
#comprobamos que los valores que quedaron fueron esos 
df_complete['target'].unique()
# Out:
# array(['>50k', '<=50k', nan], dtype=object)

# %%
#vemos cuántos registros quedaron con la separación de target que realizamos 
df_complete.groupby(by='target').count()
# Out:
#           age    sex   race  country  education  education-Num  \
# target
# <=50k   28093  28093  28093    28093      28093          28093
# >50k     8881   8881   8881     8881       8881           8881
#
#         marital status  relationship  workclass  fnlwgt  capital gain  \
# target
# <=50k            28093         28092      37155   37155         37155
# >50k              8881          8881      11687   11687         11687
#
#         capital loss  hours per week  merge
# target
# <=50k          37155           37155  37155
# >50k           11687           11687  11687

# %% [markdown]
# Transormamos las columnas de sexo, raza y educación para poder analizarla posteriormente.

# %%
#comenzamos viendo cuántos valores distintos existen en la columna race
df_complete['race'].unique()
# Out:
# array([nan, ' White', ' Other', ' Black', ' Asian-Pac-Islander',
#        ' Amer-Indian-Eskimo'], dtype=object)

# %%
#modificamos los valores para que estén en minúscula y sin espacios en blanco
df_complete = df_complete.replace({'race': {' White':'white',
                                   ' Other':'other',
                                   ' Black':'black',
                                   ' Asian-Pac-Islander': 'asian-pac-islander',
                                   ' Amer-Indian-Eskimo': 'amer-indian-eskimo'}})

# %%
#comprobamos si los valores se modificaron 
df_complete['race'].unique()
# Out:
# array([nan, 'white', 'other', 'black', 'asian-pac-islander',
#        'amer-indian-eskimo'], dtype=object)

# %%
#continuamos modificando los valores de sexo, primero vemos cuáles son los valores existentes
df_complete['sex'].unique()
# Out:
# array([nan, ' Male', ' Female'], dtype=object)

# %%
#no existe variablilidad en la columna de sexo, no es necesario unificar. Unicamente borraremos los espacios en blanco y tranformalo a minuscula
df_complete = df_complete.replace({'sex': {
                                   ' Male':'male',
                                   ' Female': 'female'}})

# %%
#comprobamos que los cambios se realizaron correctamente
df_complete['sex'].unique()
# Out:
# array([nan, 'male', 'female'], dtype=object)

# %%
#vemos los valores que están en la columna educación 
df_complete['education'].unique()
# Out:
# array([nan, ' HS-grad', ' Masters', ' Prof-school', ' Bachelors', ' 11th',
#        ' Some-college', ' 9th', ' Assoc-acdm', ' Assoc-voc', ' 7th-8th',
#        ' 10th', ' Doctorate', ' 1st-4th', ' 5th-6th', ' Preschool',
#        ' 12th'], dtype=object)

# %%
#son varios los valores a los que hay quitarle el espacio y pasarlo a miniscula
df_complete['education'] = df_complete['education'].str.lower()
df_complete['education'] = df_complete['education'].str.strip()

# %%
#comprobamos haber modificado los valores correctamente
df_complete['education'].unique()
# Out:
# array([nan, 'hs-grad', 'masters', 'prof-school', 'bachelors', '11th',
#        'some-college', '9th', 'assoc-acdm', 'assoc-voc', '7th-8th',
#        '10th', 'doctorate', '1st-4th', '5th-6th', 'preschool', '12th'],
#       dtype=object)

# %% [markdown]
# **Analisis de los datos**

# %% [markdown]
# Estando ya transformadas todas las columnas que necesitamos para el análisis (race, sex, education y target) procedemos a realiazarlo.

# %% [markdown]
# Dentro del análisis nos planteamos preguntas tales como:
# - ¿Cuál es el porcentaje de mujeres con un salario mayor a 50K?¿Qué diferencia existe con los hombres?
# - ¿En su mayoría la raza blanca qué salario tiene?
# - ¿En su mayoría la raza amer-indian-eskimo qué salario tiene? ¿y la raza negra?
# - ¿Todos los que tienen un máster tienen salarios igual o mayores a 50K?

# %%
#eliminamos los valores nulos 
df_complete.dropna(inplace=True)
df_complete.shape
# Out:
# (36973, 15)

# %%
#creamos las variables que necesitamos para el analisis según los sexos 
high_salary_women = df_complete[(df_complete['sex'] == 'female') & (df_complete['target'] == '>50k')].count()
low_salary_women = df_complete[(df_complete['sex']== 'femele') & (df_complete['target'] == '<=50k')].count()
high_salary_men = df_complete[(df_complete['sex'] == 'male') & (df_complete['target'] == '>50k')].count()

# %%
print(f'El porcentaje de mujeres que tienen un salario mayor a 50K es de {round(high_salary_women[0] / df_complete.count()[0] * 100,2)} % ')
print(f' mientras el porcentaje de hombres que tienen un salario mayor a 50K es de {round((high_salary_men[0] / df_complete.count()[0]) * 100,2)} %')
# Out:
# El porcentaje de mujeres que tienen un salario mayor a 50K es de 3.63 %
#  mientras el porcentaje de hombres que tienen un salario mayor a 50K es de 20.39 %

# %%
#buscamos qué salarios tienen en su mayoría las distintas razas
white = df_complete[df_complete['race'].str.contains('white')].count()
amer_indian_eskimo = df_complete[df_complete['race'].str.contains('amer-indian-eskimo')].count()
black = df_complete[df_complete['race'].str.contains('black')].count()

#filtramos por raza y salario mayor a 50K
high_white = df_complete[(df_complete['race'] == 'white') & (df_complete['target'] == '>50k')].count()
high_amer_indian_eskimo = df_complete[(df_complete['race'] == 'amer-indian-eskimo') & (df_complete['target'] == '>50k')].count()
high_black = df_complete[(df_complete['race'] == 'black') & (df_complete['target'] == '>50k')].count()

# %%
print(f'El porcentaje de personas de raza blanca que gana por encima de 50K es de {round(high_white[0] * 100 / white[0] ,2)} %, ')
print(f'el porcentaje de personas de raza amer-indian-eskimo que gana por encima de 50K es de {round(high_amer_indian_eskimo[0] * 100 / amer_indian_eskimo[0],2)} %')
print(f'y de las personas de raza negra el {round(high_black[0] * 100 / black[0],2)}% tiene un salario mayor a 50k')
# Out:
# El porcentaje de personas de raza blanca que gana por encima de 50K es de 25.54 %,
# el porcentaje de personas de raza amer-indian-eskimo que gana por encima de 50K es de 11.57 %
# y de las personas de raza negra el 12.27% tiene un salario mayor a 50k

# %% [markdown]
# Notamos que es sustancialmente menor el porcentaje de las personas de razas americanas y las negras que ganan por encima de 50K.

# %%
masters = df_complete[df_complete['education'] == 'masters'].count()[0]
high_masters = df_complete[(df_complete['education'] == 'masters') & (df_complete['target'] == '>50k')].count()[0]
print(f'Las personas tienen un máster y son {masters} pero únicamente {high_masters} tienen un salario mayor a 50k. ')
# Out:
# Las personas tienen un máster y son 1977 pero únicamente 1101 tienen un salario mayor a 50k.
